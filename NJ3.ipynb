# %%
#New Juice 3 LinkedIn Data Analysis

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df = pd.read_csv('NeuJuice - Visit Data - 21_7_21.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 689 entries, 0 to 688
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              689 non-null    object
#  1   VisitTime       689 non-null    object
#  2   Profile         689 non-null    object
#  3   SalesProfile    689 non-null    object
#  4   Picture         689 non-null    object
#  5   Degree          689 non-null    int64
#  6   First Name      689 non-null    object
#  7   Middle Name     689 non-null    object
#  8   Last Name       689 non-null    object
#  9   Connections     689 non-null    int64
#  10  Summary         689 non-null    object
#  11  From            689 non-null    object
#  12  Title           689 non-null    object
#  13  Company         689 non-null    object
#  14  CompanyProfile  689 non-null    object
#  15  CompanyWebsite  689 non-null    object
#  16  Email           689 non-null    object
#  17  Phone           689 non-null    object
#  18  IM              689 non-null    object
#  19  Twitter         689 non-null    object
#  20  Location        689 non-null    object
#  21  Industry        689 non-null    object
#  22  My Tags         689 non-null    object
#  23  My Notes        0 non-null      float64
#  24  Unnamed: 24     0 non-null      float64
# dtypes: float64(2), int64(2), object(21)
# memory usage: 134.7+ KB

# %%
df.sample()
# Out:
#             id            VisitTime  \
# 76  id.1577238  2021/07/20 08:46:55
#
#                                       Profile  \
# 76  https://www.linkedin.com/in/gurdeepgrewal
#
#                                          SalesProfile  \
# 76  https://www.linkedin.com/sales/people/ACwAAAAY...
#
#                                               Picture  Degree First Name  \
# 76  https://media-exp3.licdn.com/dms/image/C4D03AQ...       1    Gurdeep
#
#    Middle Name Last Name  Connections  ...          CompanyWebsite  \
# 76                Grewal         5501  ...  https://www.intive.com
#
#                         Email          Phone IM         Twitter  \
# 76  gurdeepgrewal25@gmail.com  44 7769934138     gurdeepsgrewal
#
#                            Location                             Industry  \
# 76  Slough, England, United Kingdom  Information Technology and Services
#
#                                               My Tags My Notes Unnamed: 24
# 76  |Sent Connection Request|Sent brand refresh bl...      NaN         NaN
#
# [1 rows x 25 columns]

# %%
First=df['Degree']==1

# %%
df[First]
# Out:
#                id            VisitTime  \
# 0    id.415466493  2021/07/20 08:15:15
# 1     id.48316353  2021/07/20 08:15:35
# 2     id.60326575  2021/07/20 08:15:55
# 3      id.5709523  2021/07/20 08:16:15
# 4      id.2055115  2021/07/20 08:16:35
# ..            ...                  ...
# 684   id.96855375  2021/07/21 09:24:38
# 685   id.65657991  2021/07/21 09:24:58
# 686  id.879398564  2021/07/21 09:25:17
# 687   id.42492468  2021/07/21 09:25:36
# 688  id.758092187  2021/07/21 09:25:55
#
#                                                Profile  \
# 0    https://www.linkedin.com/in/marco-morelli-phd-mba
# 1    https://www.linkedin.com/in/raskinglebheadofdi...
# 2                 https://www.linkedin.com/in/mibroome
# 3                  https://www.linkedin.com/in/safaraz
# 4         https://www.linkedin.com/in/michaelcrobinson
# ..                                                 ...
# 684  https://www.linkedin.com/in/jeevan-ratnam-6935...
# 685  https://www.linkedin.com/in/eduardo-cheveau-63...
# 686  https://www.linkedin.com/in/mr-tairisse-a-2586...
# 687           https://www.linkedin.com/in/peterogudoro
# 688          https://www.linkedin.com/in/thedanielpugh
#
#                                           SalesProfile  \
# 0    https://www.linkedin.com/sales/people/ACwAABjD...
# 1    https://www.linkedin.com/sales/people/ACwAAALh...
# 2    https://www.linkedin.com/sales/people/ACwAAAOY...
# 3    https://www.linkedin.com/sales/people/ACwAAABX...
# 4    https://www.linkedin.com/sales/people/ACwAAAAf...
# ..                                                 ...
# 684  https://www.linkedin.com/sales/people/ACwAAAXF...
# 685  https://www.linkedin.com/sales/people/ACwAAAPp...
# 686  https://www.linkedin.com/sales/people/ACwAADRq...
# 687  https://www.linkedin.com/sales/people/ACwAAAKI...
# 688  https://www.linkedin.com/sales/people/ACwAAC0v...
#
#                                                Picture  Degree First Name  \
# 0    https://media-exp3.licdn.com/dms/image/C5603AQ...       1      Marco
# 1    https://media-exp3.licdn.com/dms/image/C5603AQ...       1       Gleb
# 2    https://media-exp3.licdn.com/dms/image/C4D03AQ...       1    Michael
# 3    https://media-exp3.licdn.com/dms/image/C4D03AQ...       1    Safaraz
# 4    https://media-exp3.licdn.com/dms/image/C4D03AQ...       1       Mike
# ..                                                 ...     ...        ...
# 684  https://media-exp3.licdn.com/dms/image/C4D03AQ...       1     Jeevan
# 685  https://media-exp3.licdn.com/dms/image/C4E03AQ...       1    Eduardo
# 686  https://media-exp3.licdn.com/dms/image/C4E03AQ...       1         Mr
# 687  https://media-exp3.licdn.com/dms/image/C5603AQ...       1      Peter
# 688  https://media-exp3.licdn.com/dms/image/C4E03AQ...       1     Daniel
#
#     Middle Name Last Name  Connections  ...  \
# 0                 Morelli         1830  ...
# 1                  Raskin        25547  ...
# 2                  Broome         1450  ...
# 3                     Saf        29971  ...
# 4                Robinson         1329  ...
# ..          ...       ...          ...  ...
# 684                Ratnam          683  ...
# 685               Cheveau         1750  ...
# 686                     A           35  ...
# 687               Ogudoro         2074  ...
# 688                  Pugh          350  ...
#
#                            CompanyWebsite                              Email  \
# 0               http://www.sihealth.co.uk       marco.morelli@sihealth.co.uk
# 1               https://www.streetbeat.ai             raskinreport@gmail.com
# 2             http://www.whirelandplc.com              mike.broome@gmail.com
# 3           http://www.pathwaygroup.co.uk         safaraz@pathwaygroup.co.uk
# 4                                                   mikerobinsonvr@gmail.com
# ..                                    ...                                ...
# 684                                                    jeevanlls@yahoo.co.uk
# 685    http://www.click-entertainment.com               echeveaupp@gmail.com
# 686                                                       teeotm23@gmail.com
# 687  http://oxfordcollegeofmarketing.com/          profexamsclinic@yahoo.com
# 688     https://imperialinvestments.fund/  DanielPugh@thedecisiongroup.co.uk
#
#                   Phone           IM          Twitter  \
# 0    +44 (0) 7393818497               MarcoMorelli_05
# 1              @rasking                    GRmarketer
# 2            7801940280
# 3            1217070550  Safaraz Ali
# 4                                          GenerateUK
# ..                  ...          ...              ...
# 684
# 685                                         DuCheveau
# 686
# 687   +234(0)8023249654               profexamsclinic
# 688  +44 (0)7561 020724                 TheDanielPugh
#
#                                 Location                             Industry  \
# 0        Oxford, England, United Kingdom  Information Technology and Services
# 1                         United Kingdom  Information Technology and Services
# 2        London, England, United Kingdom                   Financial Services
# 3                         United Kingdom                 Education Management
# 4                   Greater Reading Area  Information Technology and Services
# ..                                   ...                                  ...
# 684      Sutton, England, United Kingdom                   Financial Services
# 685          London Area, United Kingdom                       Computer Games
# 686  Birmingham, England, United Kingdom                   Investment Banking
# 687                 Greater Reading Area     Professional Training & Coaching
# 688      London, England, United Kingdom                   Financial Services
#
#                                                My Tags My Notes Unnamed: 24
# 0    Sent Connection Request|Sent brand refresh blo...      NaN         NaN
# 1    |Sent Blog 1|Sent brand refresh blog|sent blog...      NaN         NaN
# 2    |Sent Blog 1|Sent Connection Request|Sent bran...      NaN         NaN
# 3    Sent brand refresh blog|sent case study|sent p...      NaN         NaN
# 4    Sent brand refresh blog|sent case study|sent p...      NaN         NaN
# ..                                                 ...      ...         ...
# 684  |Sent brand refresh blog|sent blog 2|sent case...      NaN         NaN
# 685  Ecommerce connection request|Sent brand refres...      NaN         NaN
# 686  Ecommerce connection request|Sent Connection R...      NaN         NaN
# 687  Sent Connection Request|Sent brand refresh blo...      NaN         NaN
# 688  |Sent Connection Request|Sent brand refresh bl...      NaN         NaN
#
# [684 rows x 25 columns]

# %%
first=df[First]

# %%
first
# Out:
#                id            VisitTime  \
# 0    id.415466493  2021/07/20 08:15:15
# 1     id.48316353  2021/07/20 08:15:35
# 2     id.60326575  2021/07/20 08:15:55
# 3      id.5709523  2021/07/20 08:16:15
# 4      id.2055115  2021/07/20 08:16:35
# ..            ...                  ...
# 684   id.96855375  2021/07/21 09:24:38
# 685   id.65657991  2021/07/21 09:24:58
# 686  id.879398564  2021/07/21 09:25:17
# 687   id.42492468  2021/07/21 09:25:36
# 688  id.758092187  2021/07/21 09:25:55
#
#                                                Profile  \
# 0    https://www.linkedin.com/in/marco-morelli-phd-mba
# 1    https://www.linkedin.com/in/raskinglebheadofdi...
# 2                 https://www.linkedin.com/in/mibroome
# 3                  https://www.linkedin.com/in/safaraz
# 4         https://www.linkedin.com/in/michaelcrobinson
# ..                                                 ...
# 684  https://www.linkedin.com/in/jeevan-ratnam-6935...
# 685  https://www.linkedin.com/in/eduardo-cheveau-63...
# 686  https://www.linkedin.com/in/mr-tairisse-a-2586...
# 687           https://www.linkedin.com/in/peterogudoro
# 688          https://www.linkedin.com/in/thedanielpugh
#
#                                           SalesProfile  \
# 0    https://www.linkedin.com/sales/people/ACwAABjD...
# 1    https://www.linkedin.com/sales/people/ACwAAALh...
# 2    https://www.linkedin.com/sales/people/ACwAAAOY...
# 3    https://www.linkedin.com/sales/people/ACwAAABX...
# 4    https://www.linkedin.com/sales/people/ACwAAAAf...
# ..                                                 ...
# 684  https://www.linkedin.com/sales/people/ACwAAAXF...
# 685  https://www.linkedin.com/sales/people/ACwAAAPp...
# 686  https://www.linkedin.com/sales/people/ACwAADRq...
# 687  https://www.linkedin.com/sales/people/ACwAAAKI...
# 688  https://www.linkedin.com/sales/people/ACwAAC0v...
#
#                                                Picture  Degree First Name  \
# 0    https://media-exp3.licdn.com/dms/image/C5603AQ...       1      Marco
# 1    https://media-exp3.licdn.com/dms/image/C5603AQ...       1       Gleb
# 2    https://media-exp3.licdn.com/dms/image/C4D03AQ...       1    Michael
# 3    https://media-exp3.licdn.com/dms/image/C4D03AQ...       1    Safaraz
# 4    https://media-exp3.licdn.com/dms/image/C4D03AQ...       1       Mike
# ..                                                 ...     ...        ...
# 684  https://media-exp3.licdn.com/dms/image/C4D03AQ...       1     Jeevan
# 685  https://media-exp3.licdn.com/dms/image/C4E03AQ...       1    Eduardo
# 686  https://media-exp3.licdn.com/dms/image/C4E03AQ...       1         Mr
# 687  https://media-exp3.licdn.com/dms/image/C5603AQ...       1      Peter
# 688  https://media-exp3.licdn.com/dms/image/C4E03AQ...       1     Daniel
#
#     Middle Name Last Name  Connections  ...  \
# 0                 Morelli         1830  ...
# 1                  Raskin        25547  ...
# 2                  Broome         1450  ...
# 3                     Saf        29971  ...
# 4                Robinson         1329  ...
# ..          ...       ...          ...  ...
# 684                Ratnam          683  ...
# 685               Cheveau         1750  ...
# 686                     A           35  ...
# 687               Ogudoro         2074  ...
# 688                  Pugh          350  ...
#
#                            CompanyWebsite                              Email  \
# 0               http://www.sihealth.co.uk       marco.morelli@sihealth.co.uk
# 1               https://www.streetbeat.ai             raskinreport@gmail.com
# 2             http://www.whirelandplc.com              mike.broome@gmail.com
# 3           http://www.pathwaygroup.co.uk         safaraz@pathwaygroup.co.uk
# 4                                                   mikerobinsonvr@gmail.com
# ..                                    ...                                ...
# 684                                                    jeevanlls@yahoo.co.uk
# 685    http://www.click-entertainment.com               echeveaupp@gmail.com
# 686                                                       teeotm23@gmail.com
# 687  http://oxfordcollegeofmarketing.com/          profexamsclinic@yahoo.com
# 688     https://imperialinvestments.fund/  DanielPugh@thedecisiongroup.co.uk
#
#                   Phone           IM          Twitter  \
# 0    +44 (0) 7393818497               MarcoMorelli_05
# 1              @rasking                    GRmarketer
# 2            7801940280
# 3            1217070550  Safaraz Ali
# 4                                          GenerateUK
# ..                  ...          ...              ...
# 684
# 685                                         DuCheveau
# 686
# 687   +234(0)8023249654               profexamsclinic
# 688  +44 (0)7561 020724                 TheDanielPugh
#
#                                 Location                             Industry  \
# 0        Oxford, England, United Kingdom  Information Technology and Services
# 1                         United Kingdom  Information Technology and Services
# 2        London, England, United Kingdom                   Financial Services
# 3                         United Kingdom                 Education Management
# 4                   Greater Reading Area  Information Technology and Services
# ..                                   ...                                  ...
# 684      Sutton, England, United Kingdom                   Financial Services
# 685          London Area, United Kingdom                       Computer Games
# 686  Birmingham, England, United Kingdom                   Investment Banking
# 687                 Greater Reading Area     Professional Training & Coaching
# 688      London, England, United Kingdom                   Financial Services
#
#                                                My Tags My Notes Unnamed: 24
# 0    Sent Connection Request|Sent brand refresh blo...      NaN         NaN
# 1    |Sent Blog 1|Sent brand refresh blog|sent blog...      NaN         NaN
# 2    |Sent Blog 1|Sent Connection Request|Sent bran...      NaN         NaN
# 3    Sent brand refresh blog|sent case study|sent p...      NaN         NaN
# 4    Sent brand refresh blog|sent case study|sent p...      NaN         NaN
# ..                                                 ...      ...         ...
# 684  |Sent brand refresh blog|sent blog 2|sent case...      NaN         NaN
# 685  Ecommerce connection request|Sent brand refres...      NaN         NaN
# 686  Ecommerce connection request|Sent Connection R...      NaN         NaN
# 687  Sent Connection Request|Sent brand refresh blo...      NaN         NaN
# 688  |Sent Connection Request|Sent brand refresh bl...      NaN         NaN
#
# [684 rows x 25 columns]

# %%
first.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 684 entries, 0 to 688
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              684 non-null    object
#  1   VisitTime       684 non-null    object
#  2   Profile         684 non-null    object
#  3   SalesProfile    684 non-null    object
#  4   Picture         684 non-null    object
#  5   Degree          684 non-null    int64
#  6   First Name      684 non-null    object
#  7   Middle Name     684 non-null    object
#  8   Last Name       684 non-null    object
#  9   Connections     684 non-null    int64
#  10  Summary         684 non-null    object
#  11  From            684 non-null    object
#  12  Title           684 non-null    object
#  13  Company         684 non-null    object
#  14  CompanyProfile  684 non-null    object
#  15  CompanyWebsite  684 non-null    object
#  16  Email           684 non-null    object
#  17  Phone           684 non-null    object
#  18  IM              684 non-null    object
#  19  Twitter         684 non-null    object
#  20  Location        684 non-null    object
#  21  Industry        684 non-null    object
#  22  My Tags         684 non-null    object
#  23  My Notes        0 non-null      float64
#  24  Unnamed: 24     0 non-null      float64
# dtypes: float64(2), int64(2), object(21)
# memory usage: 138.9+ KB

# %%
citynumbers=first.groupby('Location')['Degree'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(20)

# %%
citynumbers
# Out:
#                                   Location  count
# 62         London, England, United Kingdom    189
# 91  West Midlands, England, United Kingdom     89
# 55                                 Ireland     50
# 5      Birmingham, England, United Kingdom     36
# 42                  Greater Cambridge Area     32
# 10      Cambridge, England, United Kingdom     24
# 46                     Greater Oxford Area     22
# 61             London Area, United Kingdom     18
# 72        Reading, England, United Kingdom     17
# 83                          United Kingdom     16
# 23                  County Dublin, Ireland     12
# 63     Maidenhead, England, United Kingdom     12
# 76         Slough, England, United Kingdom     11
# 48                    Greater Reading Area     10
# 69         Oxford, England, United Kingdom     10
# 31          Dublin, County Dublin, Ireland      9
# 67        Newbury, England, United Kingdom      6
# 35                 England, United Kingdom      6
# 97        Windsor, England, United Kingdom      6
# 30     Dublin City, County Dublin, Ireland      5

# %%
industry=first.groupby('Industry')['Degree'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(13)

# %%
industry
# Out:
#                                Industry  count
# 32                   Financial Services    153
# 56            Marketing and Advertising     72
# 46  Information Technology and Services     51
# 80                               Retail     25
# 15                    Computer Software     21
# 54                Management Consulting     19
# 47                             Internet     17
# 25  Electrical/Electronic Manufacturing     15
# 40               Hospital & Health Care     15
# 83              Staffing and Recruiting     14
# 39                     Higher Education     12
# 16                         Construction     12
# 6                         Biotechnology     10

# %%
company
# Out:
#                                                Company  count
# 0                                                           2
# 276                                               HSBC      2
# 638                            Volkswagen Group UK Ltd      2
# 122  Cambridge University Hospitals NHS Foundation ...      2
# 625                               University of Oxford      2

# %%
title=first.groupby('Title')['Degree'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(15)

# %%
title
# Out:
#                                 Title  count
# 247                 Managing Director    141
# 276                 Marketing Manager     25
# 110                          Director     19
# 48            Chief Executive Officer     14
# 204                 Head Of Ecommerce     12
# 104         Digital Marketing Manager      9
# 32                                CEO      8
# 121  Director Of Business Development      8
# 17      Business Development Director      7
# 66                         Co-Founder      7
# 167       Founder & Managing Director      6
# 274                Marketing Director      6
# 337       Sales and Marketing Manager      6
# 265                  Managing Partner      5
# 162                           Founder      5

# %%
company=first.groupby('Company')['Degree'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(5)
