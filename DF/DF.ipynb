# %%
#DF LinkedIn Data Analysis March the 23rd

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df = pd.read_csv('dux-soup-visit-data@2021-03-23 12h08.csv')

# %%
df
# Out:
#                 id            VisitTime  \
# 0       id.6434782  2020/11/27 09:54:18
# 1       id.1066962  2020/11/27 10:00:43
# 2     id.652650540  2020/11/27 10:12:00
# 3      id.71008982  2020/11/27 10:13:18
# 4      id.17238385  2020/11/27 10:21:44
# ...            ...                  ...
# 5867  id.840915516  2021/02/17 14:57:41
# 5868   id.85454715  2021/02/17 14:59:04
# 5869  id.739993495  2021/02/17 16:10:59
# 5870  id.268261670  2021/02/17 16:26:19
# 5871   id.15178653  2021/02/26 12:15:43
#
#                                                 Profile  \
# 0            https://www.linkedin.com/in/garylittledyke
# 1                 https://www.linkedin.com/in/drewellis
# 2                https://www.linkedin.com/in/nath-aston
# 3     https://www.linkedin.com/in/osei-akoto-william...
# 4           https://www.linkedin.com/in/johnathanbrooks
# ...                                                 ...
# 5867  https://www.linkedin.com/in/matt-williams-b107...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5872 entries, 0 to 5871
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               5872 non-null   object
#  1   VisitTime        5872 non-null   object
#  2   Profile          5872 non-null   object
#  3   SalesProfile     5872 non-null   object
#  4   Picture          5872 non-null   object
#  5   Degree           5872 non-null   object
#  6   First Name       5872 non-null   object
#  7   Middle Name      5872 non-null   object
#  8   Last Name        5872 non-null   object
#  9   Connections      5872 non-null   int64
#  10  Summary          5872 non-null   object
#  11  From             5872 non-null   object
#  12  Title            5872 non-null   object
#  13  Company          5872 non-null   object
#  14  CompanyProfile   5872 non-null   object
#  15  CompanyWebsite   5872 non-null   object
# ...

# %%
df.sample()
# Out:
#                 id            VisitTime  \
# 4103  id.138458939  2021/01/22 13:04:23
#
#                                                 Profile  \
# 4103  https://www.linkedin.com/in/rana-rananjay-sing...
#
#                                            SalesProfile  \
# 4103  https://www.linkedin.com/sales/people/ACwAAAhA...
#
#                                                 Picture Degree First Name  \
# 4103  https://media-exp1.licdn.com/dms/image/C5603AQ...      1       Rana
#
#      Middle Name Last Name  Connections  ...                    Email  \
# 4103                 Singh          937  ...  singh.ranalko@gmail.com
#
#               Phone        IM Twitter                       Location  \
# 4103  +919984779753  wapfluid          Lucknow, Uttar Pradesh, India
#
#                                  Industry  \
# 4103  Information Technology and Services
#
#                                                My Tags PersonalWebsite  \
# ...

# %%
First=df['Degree']=='1'

# %%
First
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 5867    True
# 5868    True
# 5869    True
# 5870    True
# 5871    True
# Name: Degree, Length: 5872, dtype: bool

# %%
first=df[First]

# %%
first
# Out:
#                 id            VisitTime  \
# 0       id.6434782  2020/11/27 09:54:18
# 1       id.1066962  2020/11/27 10:00:43
# 2     id.652650540  2020/11/27 10:12:00
# 3      id.71008982  2020/11/27 10:13:18
# 4      id.17238385  2020/11/27 10:21:44
# ...            ...                  ...
# 5867  id.840915516  2021/02/17 14:57:41
# 5868   id.85454715  2021/02/17 14:59:04
# 5869  id.739993495  2021/02/17 16:10:59
# 5870  id.268261670  2021/02/17 16:26:19
# 5871   id.15178653  2021/02/26 12:15:43
#
#                                                 Profile  \
# 0            https://www.linkedin.com/in/garylittledyke
# 1                 https://www.linkedin.com/in/drewellis
# 2                https://www.linkedin.com/in/nath-aston
# 3     https://www.linkedin.com/in/osei-akoto-william...
# 4           https://www.linkedin.com/in/johnathanbrooks
# ...                                                 ...
# 5867  https://www.linkedin.com/in/matt-williams-b107...
# ...

# %%
cities=first.groupby('Location')['Degree'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(5)

# %%
cities
# Out:
#                                Location  count
# 729     London, England, United Kingdom   1002
# 464      Greater Brighton and Hove Area    870
# 1185                     United Kingdom    260
# 154   Brighton, England, United Kingdom    121
# 601       Hove, England, United Kingdom    119

# %%
industry=first.groupby('Industry')['Degree'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(10)

# %%
industry
# Out:
#                                 Industry  count
# 83             Marketing and Advertising    823
# 65   Information Technology and Services    743
# 109     Professional Training & Coaching    628
# 56          Health, Wellness and Fitness    287
# 80                 Management Consulting    286
# 44                    Financial Services    166
# 126              Staffing and Recruiting    154
# 26                     Computer Software    153
# 69                              Internet    144
# 36                  Education Management    135

# %%
company=first.groupby('Company')['Degree'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(10)

# %%
company
# Out:
#                          Company  count
# 3770               Self-employed     77
# 0                                    46
# 1610                   Freelance     30
# 3761               Self Employed     28
# 1556                      Fiverr     23
# 4785  West Sussex County Council     19
# 4632                      Upwork     17
# 1439                    Ericsson     14
# 4622        University of Sussex     12
# 264             American Express     12

# %%
title=first.groupby('Title')['Degree'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(5)

# %%
title
# Out:
#                   Title  count
# 1042           Director    187
# 2308  Managing Director    131
# 2580              Owner    126
# 1426            Founder    112
# 769          Consultant     63

# %%
2+2+9+0+0+7+8+7+8
# Out:
# 43
