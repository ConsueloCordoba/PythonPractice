# %%
#Jillian LinkedIn Data Analysis

# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
df = pd.read_csv('dux-soup-visit-data@2021-04-15 09h42.csv')

# %%
df
# Out:
#                id            VisitTime  \
# 0    id.824000298  2021/04/09 09:01:29
# 1    id.570269871  2021/04/09 09:02:53
# 2    id.637216284  2021/04/09 09:04:17
# 3     id.33795011  2021/04/09 09:05:43
# 4    id.778158092  2021/04/09 09:07:06
# ..            ...                  ...
# 322  id.134711932  2021/04/15 09:36:18
# 323  id.329655253  2021/04/15 09:38:21
# 324  id.139548691  2021/04/15 09:39:45
# 325  id.255008886  2021/04/15 09:41:10
# 326   id.65608205  2021/04/15 09:42:33
#
#                                                Profile  \
# 0    https://www.linkedin.com/in/fangyi-liao-036b581ab
# 1     https://www.linkedin.com/in/dena-adams-353b9513a
# 2    https://www.linkedin.com/in/catherine-beresfor...
# 3    https://www.linkedin.com/in/angelica-cole-36b399b
# 4    https://www.linkedin.com/in/misha-anya-patel-b...
# ..                                                 ...
# 322  https://www.linkedin.com/in/rhian-bowler-36414639
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 327 entries, 0 to 326
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              327 non-null    object
#  1   VisitTime       327 non-null    object
#  2   Profile         327 non-null    object
#  3   SalesProfile    327 non-null    object
#  4   Picture         327 non-null    object
#  5   Degree          327 non-null    int64
#  6   First Name      327 non-null    object
#  7   Middle Name     327 non-null    object
#  8   Last Name       327 non-null    object
#  9   Connections     327 non-null    int64
#  10  Summary         327 non-null    object
#  11  From            327 non-null    object
#  12  Title           327 non-null    object
#  13  Company         327 non-null    object
#  14  CompanyProfile  327 non-null    object
#  15  CompanyWebsite  327 non-null    object
#  16  Email           327 non-null    object
# ...

# %%
df.sample()
# Out:
#              id            VisitTime  \
# 55  id.58480657  2021/04/09 12:56:48
#
#                                               Profile  \
# 55  https://www.linkedin.com/in/paul-mccalla-b8170217
#
#                                          SalesProfile  \
# 55  https://www.linkedin.com/sales/people/ACwAAAN8...
#
#                                               Picture  Degree First Name  \
# 55  https://media-exp1.licdn.com/dms/image/C4D03AQ...       1       Paul
#
#    Middle Name Last Name  Connections  ...         CompanyWebsite  \
# 55               Mccalla         1662  ...  http://www.bmet.ac.uk
#
#                  Email Phone IM Twitter  \
# 55  peemac@hotmail.com
#
#                                   Location              Industry  \
# 55  West Midlands, England, United Kingdom  Education Management
#
#                           My Tags My Notes Unnamed: 24
# 55  |🦆-default-invited|sent ebook      NaN         NaN
#
# [1 rows x 25 columns]

# %%
First=df['Degree']==1

# %%
First
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 322    False
# 323    False
# 324    False
# 325    False
# 326    False
# Name: Degree, Length: 327, dtype: bool

# %%
first=df[First]

# %%
first
# Out:
#                id            VisitTime  \
# 48   id.375851634  2021/04/09 11:50:20
# 49   id.311675826  2021/04/09 12:30:31
# 50   id.479518560  2021/04/09 12:47:48
# 51   id.412634331  2021/04/09 12:51:39
# 52    id.90682559  2021/04/09 12:52:42
# ..            ...                  ...
# 313  id.338817631  2021/04/14 17:24:36
# 314  id.222075658  2021/04/14 17:26:02
# 315  id.191633562  2021/04/14 17:27:31
# 316  id.784226470  2021/04/14 17:29:38
# 317  id.480842524  2021/04/15 09:13:52
#
#                                                Profile  \
# 48                 https://www.linkedin.com/in/chloeng
# 49    https://www.linkedin.com/in/pamelalangancoaching
# 50   https://www.linkedin.com/in/imyad-majid-20070b114
# 51      https://www.linkedin.com/in/sophielaurennaylor
# 52              https://www.linkedin.com/in/leedmorgan
# ..                                                 ...
# 313  https://www.linkedin.com/in/mark-hendzel-02757795
# ...

# %%
cities=first.groupby('Location')['Degree'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(10)

# %%
cities
# Out:
#                                   Location  count
# 44         London, England, United Kingdom     24
# 72                          United Kingdom     11
# 78  West Midlands, England, United Kingdom      5
# 50  Milton Keynes, England, United Kingdom      3
# 42      Liverpool, England, United Kingdom      3
# 3         Bristol, England, United Kingdom      3
# 25                      Greater Leeds Area      2
# 27                     Greater Oxford Area      2
# 18                  Greater Cambridge Area      2
# 54     Nottingham, England, United Kingdom      2

# %%
industry=first.groupby('Industry')['Degree'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(35)

# %%
industry
# Out:
#                             Industry  count
# 0               Education Management     85
# 1                   Higher Education     48
# 2  Nonprofit Organization Management      1
# 3        Primary/Secondary Education      1

# %%
title=first.groupby('Title')['Degree'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(10)

# %%
title
# Out:
#                                                 Title  count
# 6                                      Career Advisor     17
# 48                                 Employment Advisor     10
# 8                                        Career Coach      6
# 56                              Employment Specialist      4
# 4                        Business Development Manager      2
# 50                              Employment Consultant      2
# 28                                  Career Specialist      2
# 37               Careers and Employability Consultant      2
# 18                         Career Development Manager      2
# 72  Lecturer in Strategy, Enterprise and Sustainab...      1

# %%
company=first.groupby('Company')['Degree'] \
                             .count() \
                             .reset_index(name='count') \
                             .sort_values(['count'], ascending=False) \
                             .head(10)

# %%
company
# Out:
#                                     Company  count
# 26              Education Development Trust      4
# 63                            PeoplePlus UK      3
# 113       University of the West of England      3
# 104                University of Birmingham      2
# 54                   London Business School      2
# 76                             Seetec Pluss      2
# 77                            Self-employed      2
# 91   The Manchester Metropolitan University      2
# 21                   De Montfort University      2
# 92                      The Open University      2

# %%
first['Tags'] = first['My Tags'].str.split('|',expand=False)
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
first
# Out:
#                id            VisitTime  \
# 48   id.375851634  2021/04/09 11:50:20
# 49   id.311675826  2021/04/09 12:30:31
# 50   id.479518560  2021/04/09 12:47:48
# 51   id.412634331  2021/04/09 12:51:39
# 52    id.90682559  2021/04/09 12:52:42
# ..            ...                  ...
# 313  id.338817631  2021/04/14 17:24:36
# 314  id.222075658  2021/04/14 17:26:02
# 315  id.191633562  2021/04/14 17:27:31
# 316  id.784226470  2021/04/14 17:29:38
# 317  id.480842524  2021/04/15 09:13:52
#
#                                                Profile  \
# 48                 https://www.linkedin.com/in/chloeng
# 49    https://www.linkedin.com/in/pamelalangancoaching
# 50   https://www.linkedin.com/in/imyad-majid-20070b114
# 51      https://www.linkedin.com/in/sophielaurennaylor
# 52              https://www.linkedin.com/in/leedmorgan
# ..                                                 ...
# 313  https://www.linkedin.com/in/mark-hendzel-02757795
# ...

# %%
conversation=first['My Tags'].str.contains('conversation')

# %%
first[conversation]
# Out:
# Empty DataFrame
# Columns: [id, VisitTime, Profile, SalesProfile, Picture, Degree, First Name, Middle Name, Last Name, Connections, Summary, From, Title, Company, CompanyProfile, CompanyWebsite, Email, Phone, IM, Twitter, Location, Industry, My Tags, My Notes, Unnamed: 24, Tags]
# Index: []
#
# [0 rows x 26 columns]
